# %% [markdown]
# # Respiratory sound recognition

# %%
import os
import IPython

from scipy.io import wavfile
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import librosa
import librosa.display
from read_wav import _read_wav_

# %%
vec, tar_sr = _read_wav_("156_5b3_Pl_mc_AKGC417L.wav")
plt.plot(vec)
# Out:
# Original sr: 44100, Target sr: 4000, duration: 20.0 sec

# %% [markdown]
# wave formed data and sampling rate saved via using librosa

# %%
print(f'waveform: {y}')
print(f'sampling rate: {sr}')
# Out:
# waveform: [ 0.          0.          0.         ... -0.04020572 -0.0400573
#  -0.03980792]
# sampling rate: 44100

# %%
librosafig, ax = plt.subplots(nrows=2, ncols=1, sharex=True)

wav = librosa.display.waveshow(y, sr=sr, x_axis='time', ax=ax[0])
ax[0].set(title='time domain')
ax[0].label_outer()


D = librosa.amplitude_to_db(np.abs(librosa.stft(vec)), ref=np.max)
img = librosa.display.specshow(D, y_axis='linear', x_axis='time',sr=tar_sr, ax=ax[1])

ax[1].set(title='Linear-frequency power spectrogram')
ax[1].label_outer()

# %% [markdown]
# ## Scipy FFT solution

# %%
IPython.display.Audio('../../data/sounds/156_5b3_Pl_mc_AKGC417L.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr, sig = wavfile.read('../../data/sounds/156_5b3_Pl_mc_AKGC417L.wav')

# %%
# Plot the signal read from wav file

plt.subplot(211)
plt.title('Spectrogram of a wav file with piano music')

plt.plot(sig)
plt.xlabel('Sample')
plt.ylabel('Amplitude')

plt.subplot(212)
plt.specgram(sig,Fs=sr)
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.ylim((0,2000))

 

plt.show()
# Out:
# /Users/liki/neuefische/Respiratory_Disease_Classification/.venv/lib/python3.9/site-packages/matplotlib/axes/_axes.py:7626: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
